# %%
import pandas as pd
import scipy.stats as stats
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading the data

# %%
data_march_1 = pd.read_csv('march_riel_1.csv')
data_march_2 = pd.read_csv('march_riel_2.csv')
data_april = pd.read_csv('april_riel.csv')
data_may = pd.read_csv('may_riel.csv')

# %%
data_march_2.head()
# Out:
#        district wall_material      status  balcony  area_kitchen  area_living  \
# 0  Личаківський         цегла   відмінний      1.0          11.0         27.0
# 1  Личаківський         цегла         NaN      2.0           6.0         42.0
# 2  Франківський         цегла   відмінний      1.0          18.0         15.0
# 3  Франківський           NaN         NaN      1.0           NaN          NaN
# 4     Галицький           NaN        люкс      1.0           NaN          NaN
#
#    area  room  floor  superficiality  type_build  price
# 0    52     1      9              11         NaN  12500
# 1    58     3      5               5    Хрущовка   8500
# 2    44     1      2               3   Польський  19300
# 3    48     1      8              10         NaN  15000
# 4    50     1      8              12         NaN  30800

# %%
data_april.head()
# Out:
#        district wall_material      status  balcony  area_kitchen  area_living  \
# 0  Личаківський         цегла        люкс      1.0          15.0          NaN
# 1     Галицький         цегла        люкс      1.0           NaN         35.0
# 2  Франківський           NaN         NaN      NaN          25.0         15.0
# 3  Франківський         цегла   відмінний      1.0          18.0         15.0
# 4  Франківський           NaN   відмінний      NaN           NaN          NaN
#
#    area  room  floor  superficiality  type_build  price
# 0    52     2      2               3         NaN  19300
# 1    45     1      9              12         NaN  28900
# 2    45     1      8               9         NaN  17300
# 3    44     1      2               3   Польський  19300
# 4    83     2      4              10         NaN  34600

# %%
data_may.head()
# Out:
#          district wall_material      status  balcony  area_kitchen  \
# 0       Галицький         цегла        люкс      1.0           7.0
# 1      Сихівський           NaN        люкс      1.0           NaN
# 2    Личаківський           NaN   відмінний      1.0          10.0
# 3  Шевченківський         цегла        люкс      NaN          20.0
# 4    Личаківський         цегла        люкс      1.0          13.0
#
#    area_living  area  room  floor  superficiality     type_build  price
# 0         30.0    46     2      3               5            NaN  16000
# 1          NaN    31     1      5               9            NaN  10000
# 2          NaN    75     2      3               3   Австрійський  30800
# 3         12.0    45     1      1               9            NaN  23100
# 4          NaN    52     2      2               3            NaN  15400

# %%
data_march_2.shape
# Out:
# (3927, 12)

# %%
data_april.shape
# Out:
# (3927, 12)

# %%
data_may.shape
# Out:
# (3924, 12)

# %%
data_march_1.shape
# Out:
# (4800, 10)

# %% [markdown]
# ### Reindex each dataset for concat

# %%
data_april.index = np.arange(len(data_march_2)+1, len(data_april) + len(data_march_2) + 1)

# %%
full_data = pd.concat([data_march_2, data_april])

# %%
data_may.index = np.arange(len(full_data)+1, len(data_may) + len(full_data) + 1)

# %%
full_data = pd.concat([full_data, data_may])

# %% [markdown]
# ### Drop duplicates

# %%
full_data = full_data.drop_duplicates()

# %% [markdown]
# ### Data cleaning

# %%
full_data.isna().sum()
# Out:
# district             0
# wall_material     4275
# status            2060
# balcony           4094
# area_kitchen      4346
# area_living       5088
# area                 0
# room                 0
# floor                0
# superficiality       0
# type_build        5500
# price                0
# dtype: int64

# %%
full_data.shape
# Out:
# (6826, 12)

# %% [markdown]
# According to the terms of the website:
#  - if data doesn't have a value about information *number of balcony* this mean that number of balcony is 0
#  - *building type* is new building

# %%
full_data.balcony = full_data.balcony.fillna(0)

# %%
full_data.type_build.unique()
# Out:
# array([nan, ' Хрущовка', ' Польський', ' Чешка', ' Австрійський',
#        ' Польський люкс', ' Австрійський люкс', ' Будівля старого Львова',
#        ' Гуртожиток', ' Сталінка', ' Готелька', ' Брежнєвка', ' Особняк'],
#       dtype=object)

# %%
full_data = full_data.loc[full_data.type_build != ' Особняк']

# %%
full_data.type_build = full_data.type_build.fillna('new')

# %% [markdown]
# #### Group data by categories

# %%
replacements = {
                'new': 'new', 
                ' Хрущовка': 'old', 
                ' Чешка': 'old', 
                ' Гуртожиток': 'old', 
                ' Сталінка': 'old', 
                ' Готелька': 'old', 
                ' Брежнєвка': 'old'
}
full_data['age'] = full_data.type_build.map(replacements).fillna('his')

# %% [markdown]
# Data has more than 50 % missing values in collumn *'wall_materials'* so we need to drop these values

# %%
full_data = full_data.drop(columns = ['wall_material'], axis = 1)

# %%
full_data.isna().sum()
# Out:
# district             0
# status            2048
# balcony              0
# area_kitchen      4323
# area_living       5059
# area                 0
# room                 0
# floor                0
# superficiality       0
# type_build           0
# price                0
# age                  0
# dtype: int64

# %%
full_data.head()
# Out:
#        district      status  balcony  area_kitchen  area_living  area  room  \
# 0  Личаківський   відмінний      1.0          11.0         27.0    52     1
# 1  Личаківський         NaN      2.0           6.0         42.0    58     3
# 2  Франківський   відмінний      1.0          18.0         15.0    44     1
# 3  Франківський         NaN      1.0           NaN          NaN    48     1
# 4     Галицький        люкс      1.0           NaN          NaN    50     1
#
#    floor  superficiality  type_build  price  age
# 0      9              11         new  12500  new
# 1      5               5    Хрущовка   8500  old
# 2      2               3   Польський  19300  his
# 3      8              10         new  15000  new
# 4      8              12         new  30800  new

# %% [markdown]
# #### Transform categorial str data to int

# %%
full_data.district.unique()
# Out:
# array(['Личаківський', 'Франківський', 'Галицький', 'Шевченківський',
#        'Сихівський', 'Залізничний'], dtype=object)

# %%
string_to_number_district = {
                         'Личаківський': 1, 
                         'Галицький': 2,  
                         'Шевченківський': 3, 
                         'Сихівський': 4,
                         'Франківський': 5, 
                         'Залізничний': 6}

# %%
full_data['district'] = full_data.district.map(string_to_number_district)

# %%
full_data.head()
# Out:
#    district      status  balcony  area_kitchen  area_living  area  room  \
# 0         1   відмінний      1.0          11.0         27.0    52     1
# 1         1         NaN      2.0           6.0         42.0    58     3
# 2         5   відмінний      1.0          18.0         15.0    44     1
# 3         5         NaN      1.0           NaN          NaN    48     1
# 4         2        люкс      1.0           NaN          NaN    50     1
#
#    floor  superficiality  type_build  price  age
# 0      9              11         new  12500  new
# 1      5               5    Хрущовка   8500  old
# 2      2               3   Польський  19300  his
# 3      8              10         new  15000  new
# 4      8              12         new  30800  new

# %%
string_to_number_age = {
                         'old': 1, 
                         'his': 2,  
                         'new': 3
}

# %%
full_data.age = full_data.age.map(string_to_number_age)

# %%
full_data = full_data.drop(columns = ['type_build'], axis = 1)

# %%
full_data.isna().sum()
# Out:
# district             0
# status            2048
# balcony              0
# area_kitchen      4323
# area_living       5059
# area                 0
# room                 0
# floor                0
# superficiality       0
# price                0
# age                  0
# dtype: int64

# %% [markdown]
#  - *status* column is important column for *price* prediction, let's look for price range for each categories *'status'*
#  - before filling missed data *'status'*, work with data outliers

# %%
full_data.describe().round()
# Out:
#        district  balcony  area_kitchen  area_living     area    room   floor  \
# count    6778.0   6778.0        2455.0       1719.0   6778.0  6778.0  6778.0
# mean        3.0      0.0          17.0         36.0     65.0     2.0     5.0
# std         1.0      1.0          54.0         33.0    244.0     1.0     3.0
# min         1.0      0.0           3.0          6.0      7.0     1.0     1.0
# 25%         2.0      0.0           9.0         20.0     44.0     1.0     2.0
# 50%         3.0      0.0          13.0         32.0     52.0     2.0     4.0
# 75%         5.0      1.0          17.0         42.0     70.0     2.0     7.0
# max         6.0      4.0        1628.0        654.0  15000.0     7.0    21.0
#
#        superficiality      price     age
# count          6778.0     6778.0  6778.0
# mean              8.0    30073.0     3.0
# std               4.0   226838.0     1.0
# min               1.0       19.0     1.0
# 25%               5.0    13500.0     3.0
# 50%               9.0    17000.0     3.0
# 75%              10.0    21200.0     3.0
# max              25.0  9801000.0     3.0

# %% [markdown]
# Rent price max is 9801000, it's a big price for rent apartment, so drop all values where price > 100000 for month

# %%
full_data = full_data.loc[full_data.price < 100000]

# %% [markdown]
# The minimum rent price is 17, it's a measly price for rent apartment.
# According to the web site, we know that price rent apartments start from 7000/month,
# so values < 7000/month are outliers: this data is likely to contain data about renting a room, not an apartment

# %%
full_data = full_data.loc[full_data.price >= 7000]

# %%
full_data.status.unique()
# Out:
# array([' відмінний', nan, ' люкс', ' середній', ' без оздоблення',
#        ' потребує ремонту'], dtype=object)

# %%
full_data.shape
# Out:
# (6548, 11)

# %%
full_data.loc[full_data.status == ' без оздоблення']
# Out:
#       district           status  balcony  area_kitchen  area_living  area  \
# 1508         3   без оздоблення      1.0          12.0         30.0    50
#
#       room  floor  superficiality  price  age
# 1508     2      2               9  13500    3

# %%
full_data = full_data.loc[full_data.status != ' без оздоблення']

# %%
full_data.loc[full_data.status == ' потребує ремонту']
# Out:
#        district             status  balcony  area_kitchen  area_living  area  \
# 7846          3   потребує ремонту      0.0           NaN          NaN    64
# 9360          2   потребує ремонту      1.0           5.0         28.0    45
# 11501         5   потребує ремонту      2.0           NaN          NaN    75
#
#        room  floor  superficiality  price  age
# 7846      2      2              10  22000    3
# 9360      2      2               2  10000    2
# 11501     4      7               9  17300    3

# %% [markdown]
# We have only one instance with *status* ' без оздоблення' and three ' потребує ремонту': remove the data for the representativeness of the sample

# %%
full_data = full_data.loc[full_data.status != ' потребує ремонту']

# %%
full_data.loc[full_data.status.isna()].describe().round()
# Out:
#        district  balcony  area_kitchen  area_living     area    room   floor  \
# count    1965.0   1965.0         260.0        192.0   1965.0  1965.0  1965.0
# mean        4.0      0.0          13.0         37.0     66.0     2.0     5.0
# std         1.0      0.0           8.0         30.0    339.0     1.0     3.0
# min         1.0      0.0           4.0         11.0      9.0     1.0     1.0
# 25%         2.0      0.0           8.0         25.0     43.0     1.0     2.0
# 50%         3.0      0.0          12.0         33.0     50.0     2.0     4.0
# 75%         5.0      0.0          15.0         41.0     65.0     2.0     6.0
# max         6.0      3.0          73.0        382.0  15000.0     7.0    21.0
#
#        superficiality    price     age
# count          1965.0   1965.0  1965.0
# mean              8.0  17712.0     3.0
# std               4.0   8181.0     0.0
# min               1.0   7000.0     1.0
# 25%               5.0  12000.0     3.0
# 50%               9.0  16000.0     3.0
# 75%              10.0  21200.0     3.0
# max              25.0  76900.0     3.0

# %%
full_data.status.unique()
# Out:
# array([' відмінний', nan, ' люкс', ' середній'], dtype=object)

# %% [markdown]
# Transform categories data str to int

# %%
string_to_number_status = {
                         ' середній': 1, 
                         ' відмінний': 2,  
                         ' люкс': 3
}

# %%
full_data.status = full_data.status.map(string_to_number_status)

# %% [markdown]
# #### Overview the data with each category *status*

# %%
full_data.loc[full_data.status == 1].describe().round()
# Out:
#        district  status  balcony  area_kitchen  area_living   area   room  \
# count     292.0   292.0    292.0         133.0         93.0  292.0  292.0
# mean        4.0     1.0      1.0          11.0         34.0   52.0    2.0
# std         2.0     0.0      1.0          10.0         32.0   28.0    1.0
# min         1.0     1.0      0.0           5.0          6.0   19.0    1.0
# 25%         2.0     1.0      0.0           7.0         20.0   38.0    1.0
# 50%         4.0     1.0      0.0           9.0         30.0   49.0    2.0
# 75%         5.0     1.0      1.0          11.0         41.0   63.0    2.0
# max         6.0     1.0      3.0          81.0        303.0  403.0    4.0
#
#        floor  superficiality    price    age
# count  292.0           292.0    292.0  292.0
# mean     4.0             6.0  11623.0    2.0
# std      3.0             3.0   5486.0    1.0
# min      1.0             1.0   7000.0    1.0
# 25%      2.0             4.0   8500.0    1.0
# 50%      3.0             5.0  10000.0    2.0
# 75%      5.0             9.0  13125.0    3.0
# max     11.0            16.0  71000.0    3.0

# %% [markdown]
# median price for [*status* == 1] is 10000

# %%
full_data.loc[full_data.status == 2].describe().round()
# Out:
#        district  status  balcony  area_kitchen  area_living     area    room  \
# count    2736.0  2736.0   2736.0        1347.0        890.0   2736.0  2736.0
# mean        4.0     2.0      1.0          18.0         37.0     66.0     2.0
# std         2.0     0.0      1.0          72.0         34.0    252.0     1.0
# min         1.0     2.0      0.0           3.0          8.0      7.0     1.0
# 25%         2.0     2.0      0.0          10.0         21.0     44.0     1.0
# 50%         3.0     2.0      1.0          13.0         32.0     54.0     2.0
# 75%         5.0     2.0      1.0          16.0         42.0     70.0     2.0
# max         6.0     2.0      4.0        1628.0        654.0  13000.0     7.0
#
#         floor  superficiality    price     age
# count  2736.0          2736.0   2736.0  2736.0
# mean      5.0             8.0  17809.0     3.0
# std       3.0             4.0   6606.0     1.0
# min       1.0             1.0   7000.0     1.0
# 25%       2.0             5.0  14000.0     3.0
# 50%       4.0             9.0  16500.0     3.0
# 75%       7.0            10.0  20300.0     3.0
# max      21.0            25.0  76900.0     3.0

# %% [markdown]
# median price for [*status* == 2] is 16500

# %%
full_data.loc[full_data.status == 3].describe().round()
# Out:
#        district  status  balcony  area_kitchen  area_living    area    room  \
# count    1551.0  1551.0   1551.0         619.0        464.0  1551.0  1551.0
# mean        3.0     3.0      1.0          18.0         37.0    68.0     2.0
# std         1.0     0.0      1.0          15.0         32.0    44.0     1.0
# min         1.0     3.0      0.0           3.0         10.0    15.0     1.0
# 25%         2.0     3.0      0.0          12.0         20.0    45.0     1.0
# 50%         3.0     3.0      1.0          15.0         34.0    60.0     2.0
# 75%         5.0     3.0      1.0          20.0         42.0    78.0     2.0
# max         6.0     3.0      4.0         232.0        422.0   728.0     7.0
#
#         floor  superficiality    price     age
# count  1551.0          1551.0   1551.0  1551.0
# mean      5.0             9.0  22542.0     3.0
# std       3.0             4.0   9719.0     0.0
# min       1.0             1.0   7200.0     1.0
# 25%       3.0             5.0  16000.0     3.0
# 50%       4.0             9.0  20000.0     3.0
# 75%       7.0            10.0  25000.0     3.0
# max      21.0            25.0  96100.0     3.0

# %% [markdown]
# median price for [*status* == 3] is 20000

# %% [markdown]
# Filling missed values *status* by median price

# %%
full_data.loc[full_data['status'].isnull() & (full_data['price'] <= 10000), 'status'] = 1
full_data.loc[full_data['status'].isnull() & (full_data['price'] <= 17000), 'status'] = 2
full_data.loc[full_data['status'].isnull(), 'status'] = 3

# %%
full_data.head()
# Out:
#    district  status  balcony  area_kitchen  area_living  area  room  floor  \
# 0         1     2.0      1.0          11.0         27.0    52     1      9
# 1         1     1.0      2.0           6.0         42.0    58     3      5
# 2         5     2.0      1.0          18.0         15.0    44     1      2
# 3         5     2.0      1.0           NaN          NaN    48     1      8
# 4         2     3.0      1.0           NaN          NaN    50     1      8
#
#    superficiality  price  age
# 0              11  12500    3
# 1               5   8500    1
# 2               3  19300    2
# 3              10  15000    3
# 4              12  30800    3

# %% [markdown]
# #### Concat the data

# %% [markdown]
# data_march_1 is already preprocessed so just merge

# %%
data_march_1.index = np.arange(len(full_data)+1, len(data_march_1) + len(full_data) + 1)
full_data = pd.concat([full_data, data_march_1])

# %%
full_data = full_data.drop_duplicates()

# %%
full_data.shape
# Out:
# (11065, 11)

# %%
full_data.describe().round()
# Out:
#        district   status  balcony  area_kitchen  area_living     area  \
# count   11065.0  11065.0  11065.0        7015.0       6312.0  11065.0
# mean        3.0      2.0      0.0          16.0         38.0     66.0
# std         1.0      1.0      1.0          32.0         20.0    191.0
# min         1.0      1.0      0.0           3.0          6.0      7.0
# 25%         2.0      2.0      0.0          14.0         26.0     45.0
# 50%         3.0      2.0      0.0          15.0         39.0     58.0
# 75%         5.0      3.0      1.0          16.0         42.0     72.0
# max         6.0      3.0      4.0        1628.0        654.0  15000.0
#
#           room    floor  superficiality    price      age
# count  11065.0  11065.0          6381.0  11065.0  11065.0
# mean       2.0      5.0             8.0  19552.0      3.0
# std        1.0      3.0             4.0   8516.0      1.0
# min        1.0      0.0             1.0   1500.0      1.0
# 25%        1.0      2.0             5.0  14000.0      3.0
# 50%        2.0      4.0             9.0  17550.0      3.0
# 75%        2.0      7.0            10.0  23100.0      3.0
# max        7.0     30.0            25.0  96100.0      3.0

# %%
full_data.isna().sum()
# Out:
# district             0
# status               0
# balcony              0
# area_kitchen      4050
# area_living       4753
# area                 0
# room                 0
# floor                0
# superficiality    4684
# price                0
# age                  0
# dtype: int64

# %% [markdown]
# Column *superficiality* has more than 50 % missed values, so drop this column

# %%
full_data = full_data.drop(columns = ['superficiality'], axis = 1)

# %%
full_data.loc[full_data.area > 300]
# Out:
#        district  status  balcony  area_kitchen  area_living     area  room  \
# 1549        5.0     2.0      2.0          15.0         55.0   1051.0     3
# 2129        2.0     1.0      0.0          81.0        303.0    403.0     1
# 2130        6.0     2.0      1.0           6.0          NaN    422.0     2
# 2969        5.0     2.0      1.0           NaN          NaN    594.0     2
# 3011        4.0     2.0      2.0          15.0         55.0   1051.0     3
# 3341        5.0     2.0      0.0           NaN          NaN    700.0     2
# 3562        5.0     2.0      0.0           7.0        294.0    364.0     1
# 3906        5.0     2.0      1.0          75.0         20.0    379.0     1
# 4610        2.0     3.0      0.0           NaN          NaN    376.0     1
# 4677        2.0     2.0      1.0           7.0          NaN  13000.0     2
# 4972        3.0     2.0      0.0         173.0        327.0    653.0     2
# 5068        3.0     3.0      0.0           NaN          NaN    425.0     1
# 5332        5.0     2.0      0.0           NaN          NaN    644.0     1
# 6122        5.0     3.0      0.0           NaN          NaN    644.0     1
# 6332        5.0     3.0      0.0           NaN          NaN    593.0     1
# 6335        2.0     2.0      0.0          61.0          NaN    471.0     1
# 6599        2.0     2.0      0.0           NaN          NaN    400.0     2
# 6993        3.0     2.0      0.0           NaN          NaN    376.0     1
# 7050        1.0     1.0      0.0          65.0          NaN    479.0     1
# 7557        5.0     2.0      0.0          73.0        382.0    569.0     2
# 7872        3.0     3.0      0.0         232.0        284.0    696.0     2
# 7898        5.0     2.0      1.0         129.0        654.0    979.0     3
# 7908        5.0     2.0      1.0         103.0        202.0    446.0     1
# 7942        3.0     3.0      2.0          15.0         42.0    728.0     2
# 8079        3.0     2.0      0.0           NaN          NaN  15000.0     1
# 9207        3.0     2.0      0.0           NaN          NaN    400.0     1
# 9579        5.0     3.0      0.0           NaN          NaN    644.0     2
# 9889        3.0     1.0      1.0           NaN          NaN    401.0     1
# 10508       5.0     2.0      1.0           NaN          NaN    368.0     1
# 11645       3.0     2.0      0.0          24.0          NaN    696.0     2
#
#        floor  price  age
# 1549       7  22700    3
# 2129       2   8000    2
# 2130       3  10000    2
# 2969       7  15000    1
# 3011       7  22700    3
# 3341       7  27000    3
# 3562       9  11600    1
# 3906       3  25000    3
# 4610       4  19300    3
# 4677       1  13000    2
# 4972       6  28900    3
# 5068       7  25000    3
# 5332       3  27000    3
# 6122       3  27000    3
# 6332       9  25000    3
# 6335       6  13000    3
# 6599       2  15400    3
# 6993       4  19300    3
# 7050       9   9000    1
# 7557       3  12000    2
# 7872       1  25000    1
# 7898       2  25000    2
# 7908       5  15400    3
# 7942       8  30800    3
# 8079       1  15000    3
# 9207       5  14000    3
# 9579       3  38500    3
# 9889       1   7500    3
# 10508      5  10500    1
# 11645      1  27000    3

# %%
full_data = full_data.loc[full_data.area < 200]

# %%
full_data = full_data.loc[full_data.price >= 7000]

# %%
full_data.describe().round()
# Out:
#        district   status  balcony  area_kitchen  area_living     area  \
# count   10979.0  10979.0  10979.0        6962.0       6263.0  10979.0
# mean        3.0      2.0      0.0          16.0         37.0     62.0
# std         1.0      1.0      1.0          32.0         16.0     23.0
# min         1.0      1.0      0.0           3.0          6.0      7.0
# 25%         2.0      2.0      0.0          14.0         26.0     45.0
# 50%         3.0      2.0      0.0          15.0         39.0     57.0
# 75%         5.0      3.0      1.0          16.0         42.0     72.0
# max         6.0      3.0      4.0        1628.0        444.0    180.0
#
#           room    floor    price      age
# count  10979.0  10979.0  10979.0  10979.0
# mean       2.0      5.0  19455.0      3.0
# std        1.0      3.0   8263.0      1.0
# min        1.0      0.0   7000.0      1.0
# 25%        1.0      2.0  14000.0      3.0
# 50%        2.0      4.0  17550.0      3.0
# 75%        2.0      7.0  23100.0      3.0
# max        7.0     30.0  90000.0      3.0

# %% [markdown]
# Filling missed data using same approach as with *status* column

# %%
full_data.loc[full_data.area <= 15, 'area_kitchen'] = full_data.loc[full_data.area <= 15, 'area_kitchen'].fillna(3)
full_data.loc[full_data.area <= 15, 'area_living'] = full_data.loc[full_data.area <= 15, 'area_living'].fillna(8)
full_data.loc[full_data.area <= 46, 'area_kitchen'] = full_data.loc[full_data.area <= 46, 'area_kitchen'].fillna(15)
full_data.loc[full_data.area <= 46, 'area_living'] = full_data.loc[full_data.area <= 46, 'area_living'].fillna(27)
full_data.loc[full_data.area <= 59, 'area_kitchen'] = full_data.loc[full_data.area <= 59, 'area_kitchen'].fillna(15)
full_data.loc[full_data.area <= 59, 'area_living'] = full_data.loc[full_data.area <= 59, 'area_living'].fillna(39)
full_data.loc[full_data.area > 59, 'area_kitchen'] = full_data.loc[full_data.area > 59, 'area_kitchen'].fillna(16)
full_data.loc[full_data.area > 59 , 'area_living'] = full_data.loc[full_data.area > 59, 'area_living'].fillna(42)

# %%
full_data.shape
# Out:
# (10979, 10)

# %%
full_data.describe().round()
# Out:
#        district   status  balcony  area_kitchen  area_living     area  \
# count   10979.0  10979.0  10979.0       10979.0      10979.0  10979.0
# mean        3.0      2.0      0.0          16.0         37.0     62.0
# std         1.0      1.0      1.0          25.0         13.0     23.0
# min         1.0      1.0      0.0           3.0          6.0      7.0
# 25%         2.0      2.0      0.0          15.0         27.0     45.0
# 50%         3.0      2.0      0.0          15.0         39.0     57.0
# 75%         5.0      3.0      1.0          16.0         42.0     72.0
# max         6.0      3.0      4.0        1628.0        444.0    180.0
#
#           room    floor    price      age
# count  10979.0  10979.0  10979.0  10979.0
# mean       2.0      5.0  19455.0      3.0
# std        1.0      3.0   8263.0      1.0
# min        1.0      0.0   7000.0      1.0
# 25%        1.0      2.0  14000.0      3.0
# 50%        2.0      4.0  17550.0      3.0
# 75%        2.0      7.0  23100.0      3.0
# max        7.0     30.0  90000.0      3.0

# %% [markdown]
# #### Work with outliers

# %%
full_data = full_data.loc[full_data.area_kitchen < 100]

# %%
full_data = full_data.loc[full_data.area_living <= 200]

# %%
full_data.describe().round()
# Out:
#        district   status  balcony  area_kitchen  area_living     area  \
# count   10960.0  10960.0  10960.0       10960.0      10960.0  10960.0
# mean        3.0      2.0      0.0          15.0         37.0     62.0
# std         1.0      1.0      1.0           4.0         11.0     23.0
# min         1.0      1.0      0.0           3.0          6.0      7.0
# 25%         2.0      2.0      0.0          15.0         27.0     45.0
# 50%         3.0      2.0      0.0          15.0         39.0     57.0
# 75%         5.0      3.0      1.0          16.0         42.0     72.0
# max         6.0      3.0      4.0          83.0        175.0    180.0
#
#           room    floor    price      age
# count  10960.0  10960.0  10960.0  10960.0
# mean       2.0      5.0  19445.0      3.0
# std        1.0      3.0   8259.0      1.0
# min        1.0      0.0   7000.0      1.0
# 25%        1.0      2.0  14000.0      3.0
# 50%        2.0      4.0  17550.0      3.0
# 75%        2.0      7.0  23100.0      3.0
# max        7.0     30.0  90000.0      3.0

# %% [markdown]
# #### Save ready dataset

# %%
# uncomment if need it 
# full_data.to_csv('after_preprocessing.csv', encoding='utf-8', index=False)
